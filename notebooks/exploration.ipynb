# %% [markdown]
# # FraudGuard AI - Exploration Notebook
#
# Use this notebook for quick exploratory analysis after running `python train_model.py`.

# %%
import pandas as pd

df = pd.read_csv('../data/transactions.csv')
df.head()

# %%
df['fraud'].value_counts(normalize=True)

# %%
df.groupby('transaction_type')['fraud'].mean().sort_values(ascending=False)
